# %% [markdown]
# <a href="https://colab.research.google.com/github/krackofficer/Statistics-Advanced-1-/blob/main/Statistics_Advancedipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## STATISTICS ADVANCED 1 ASSIGNMENT

# %%
## 1. Explain the properties of the F-distribution.

# %%
"""
The F-distribution has the following properties:

It is a continuous probability distribution.

It is defined only for positive values (F ≥ 0).

It is positively skewed.

It is characterized by two degrees of freedom: one for the numerator (df1) and one for the denominator (df2).

As the degrees of freedom increase, the distribution becomes more symmetric.

It is used primarily in hypothesis testing, especially in comparing variances and in ANOVA.

"""
# Out:
# '\nThe F-distribution has the following properties:\n\nIt is a continuous probability distribution.\n\nIt is defined only for positive values (F ≥ 0).\n\nIt is positively skewed.\n\nIt is characterized by two degrees of freedom: one for the numerator (df1) and one for the denominator (df2).\n\nAs the degrees of freedom increase, the distribution becomes more symmetric.\n\nIt is used primarily in hypothesis testing, especially in comparing variances and in ANOVA.\n\n'

# %%
## 2.In which types of statistical tests is the F-distribution used, and why is it appropriate for these tests?

# %%
"""
The F-distribution is used in:

ANOVA (Analysis of Variance): to test whether the means of multiple groups are equal.

F-test for equality of variances: to compare two population variances.

Regression analysis: to test the overall significance of a model.

It is appropriate because it models the ratio of two variances, which is what these tests often require.
"""
# Out:
# '\nThe F-distribution is used in:\n\nANOVA (Analysis of Variance): to test whether the means of multiple groups are equal.\n\nF-test for equality of variances: to compare two population variances.\n\nRegression analysis: to test the overall significance of a model.\n\nIt is appropriate because it models the ratio of two variances, which is what these tests often require.\n'

# %%
## 3. What are the key assumptions required for conducting an F-test to compare the variances of two populations?

# %%
"""
 The key assumptions are:

The two populations are normally distributed.

The samples are independent of each other.

The data are continuous and measured on an interval or ratio scale.
"""
# Out:
# '\n The key assumptions are:\n\nThe two populations are normally distributed.\n\nThe samples are independent of each other.\n\nThe data are continuous and measured on an interval or ratio scale.\n'

# %%
## 4.What is the purpose of ANOVA, and how does it differ from a t-test?

# %%
"""
 ANOVA is used to determine if there are statistically significant differences between the means of three or more independent groups. It differs from a t-test in that:

A t-test compares means between two groups.

ANOVA can compare means among three or more groups in a single test, reducing Type I error.
"""
# Out:
# '\n ANOVA is used to determine if there are statistically significant differences between the means of three or more independent groups. It differs from a t-test in that:\n\nA t-test compares means between two groups.\n\nANOVA can compare means among three or more groups in a single test, reducing Type I error.\n'

# %%
## 5.Explain when and why you would use a one-way ANOVA instead of multiple t-tests when comparing more than two groups.

# %%
"""
 A one-way ANOVA is used instead of multiple t-tests when comparing three or more group means because:

It controls the overall Type I error rate better.

Performing multiple t-tests increases the chance of incorrectly rejecting at least one true null hypothesis.
"""
# Out:
# '\n A one-way ANOVA is used instead of multiple t-tests when comparing three or more group means because:\n\nIt controls the overall Type I error rate better.\n\nPerforming multiple t-tests increases the chance of incorrectly rejecting at least one true null hypothesis.\n'

# %%
## 6. Explain how variance is partitioned in ANOVA into between-group variance and within-group variance. How does this partitioning contribute to the calculation of the F-statistic?

# %%
"""
In ANOVA:

Between-group variance measures variation due to interaction between the groups.

Within-group variance measures variation within each group.

The F-statistic is calculated as:
𝐹
=
Between-group variance
Within-group variance
F=
Within-group variance
Between-group variance
​


This ratio indicates whether the group means are significantly different from each other.
"""
# Out:
# '\nIn ANOVA:\n\nBetween-group variance measures variation due to interaction between the groups.\n\nWithin-group variance measures variation within each group.\n\nThe F-statistic is calculated as: \n𝐹\n=\nBetween-group\xa0variance\nWithin-group\xa0variance\nF= \nWithin-group\xa0variance\nBetween-group\xa0variance\n\u200b\n \n\nThis ratio indicates whether the group means are significantly different from each other.\n'

# %%
## 7.Compare the classical (frequentist) approach to ANOVA with the Bayesian approach. What are the key differences in terms of how they handle uncertainty, parameter estimation, and hypothesis testing?

# %%
"""
Frequentist ANOVA relies on p-values, assumes fixed parameters, and uses sample data to make inferences.

Bayesian ANOVA uses probability distributions for parameters, incorporates prior knowledge, and computes posterior distributions.

Key differences:

Uncertainty: Bayesian models uncertainty in the parameters; frequentist models uncertainty in the data.

Estimation: Frequentist uses point estimates; Bayesian gives a full posterior distribution.

Hypothesis testing: Frequentist uses p-values; Bayesian uses credible intervals or Bayes factors.
"""
# Out:
# '\nFrequentist ANOVA relies on p-values, assumes fixed parameters, and uses sample data to make inferences.\n\nBayesian ANOVA uses probability distributions for parameters, incorporates prior knowledge, and computes posterior distributions.\n\nKey differences:\n\nUncertainty: Bayesian models uncertainty in the parameters; frequentist models uncertainty in the data.\n\nEstimation: Frequentist uses point estimates; Bayesian gives a full posterior distribution.\n\nHypothesis testing: Frequentist uses p-values; Bayesian uses credible intervals or Bayes factors.\n'

# %%
## 8. Question: You have two sets of data representing the incomes of two different professions
## Profession A: [48, 52, 55, 60, 62]
## Profession B: [45, 50, 55, 52, 47]
## Perform an F-test to determine if the variances of the two professions' incomes are equal. What are your conclusions based on the F-test?
## Task: Use Python to calculate the F-statistic and p-value for the given data.
## Objective: Gain experience in performing F-tests and interpreting the results in terms of variance comparison.

# %%
import scipy.stats as stats

# Data
profession_a = [48, 52, 55, 60, 62]
profession_b = [45, 50, 55, 52, 47]

# Variances
var_a = stats.tvar(profession_a)
var_b = stats.tvar(profession_b)

# F-statistic (larger variance / smaller variance)
f_statistic = var_a / var_b if var_a > var_b else var_b / var_a
df1 = len(profession_a) - 1
df2 = len(profession_b) - 1

# Two-tailed p-value
p_value = 2 * (1 - stats.f.cdf(f_statistic, df1, df2))

print(f"F-statistic: {f_statistic:.4f}")
print(f"p-value: {p_value:.4f}")

## Interpretation: If the p-value is less than 0.05, we reject the null hypothesis and conclude the variances are significantly different.
# Out:
# F-statistic: 2.0892
# p-value: 0.4930

# %%
## 9.Conduct a one-way ANOVA to test whether there are any statistically significant differences in average heights between three different regions with the following data
## Region A: [160, 162, 165, 158, 164]
## Region B: [172, 175, 170, 168, 174]
## Region C: [180, 182, 179, 185, 183]
## Task: Write Python code to perform the one-way ANOVA and interpret the results
## Objective: Learn how to perform one-way ANOVA using Python and interpret F-statistic and p-value

# %%
from scipy.stats import f_oneway

# Data
region_a = [160, 162, 165, 158, 164]
region_b = [172, 175, 170, 168, 174]
region_c = [180, 182, 179, 185, 183]

# One-way ANOVA
f_stat, p_val = f_oneway(region_a, region_b, region_c)

print(f"F-statistic: {f_stat:.4f}")
print(f"p-value: {p_val:.4f}")

## Interpretation: If the p-value is less than 0.05, we conclude that there is a significant difference in average heights among the three regions.
# Out:
# F-statistic: 67.8733
# p-value: 0.0000

# %%
## Thanks for this project.
